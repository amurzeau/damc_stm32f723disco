# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 999, 1000)
y = np.sin(x*2*np.pi*1000/48000)
m1 = np.sqrt(2 - 2*np.cos(2*np.pi*1000/48000));
plt.plot(x, y)
y = np.diff(y)
x = x[:999]
plt.plot(x, y)
plt.show()
[m1, max(y)]
# Out:
# [0.13080625846028635, 0.1305261922200701]

# %%
np.linspace(0, 4, 5)
# Out:
# array([0., 1., 2., 3., 4.])
